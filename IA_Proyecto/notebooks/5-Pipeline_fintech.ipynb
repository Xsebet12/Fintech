# %% [markdown]
# # 5. Pipeline final Fintech
#
# Notebook de orquestación final para demostrar el flujo completo del proyecto.
#
# Este notebook ejecuta la secuencia completa:
# 1. Ingesta
# 2. Transformación
# 3. Validación
# 4. KPI
# 5. Carga

# %%
from pathlib import Path
import sys

current_dir = Path.cwd().resolve()
project_root = current_dir if (current_dir / 'pipeline.py').exists() else current_dir.parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from pipeline import run_pipeline

# %%
resultado = run_pipeline()
resultado['kpis']

# %%
resultado['carga']

# %% [markdown]
# Este notebook sirve como demo final para mostrar que la solución procesa, valida, calcula KPIs y deja artefactos versionados.
