# %% [markdown]
# # 1. Ingesta de datos Fintech
#
# Notebook de apoyo para la primera etapa del pipeline ETL.
#
# Objetivo:
# - Leer el archivo raw de transacciones.
# - Revisar forma y columnas del dataset.
# - Dejar trazabilidad de la ingesta en metadatos.

# %%
from pathlib import Path
import sys

current_dir = Path.cwd().resolve()
project_root = current_dir if (current_dir / 'pipeline.py').exists() else current_dir.parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import pandas as pd
from ingestion.lectura_csv import leer_datos_csv

# %%
raw_path = '../data/raw/fintech_raw.csv'
df_ingesta = leer_datos_csv(raw_path)
df_ingesta.head()

# %%
print('Filas:', len(df_ingesta))
print('Columnas:', list(df_ingesta.columns))
print(df_ingesta.info())

# %% [markdown]
# La ingesta guarda automáticamente el JSON de metadatos asociado al archivo leído.
# Ese archivo queda en la carpeta `IA_Proyecto/data/metadata/`.
