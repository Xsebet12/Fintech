# %% [markdown]
# # Pipeline Fintech
#
# Notebook de ejecución sencilla para la demo final del proyecto.
#
# Este notebook vive en la raíz del repositorio y ejecuta el flujo completo:
# 1. Ingesta
# 2. Transformación
# 3. Validación
# 4. KPI
# 5. Carga

# %%
from pathlib import Path
import sys

current_dir = Path.cwd().resolve()
project_root = current_dir if (current_dir / 'pipeline.py').exists() else current_dir.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from pipeline import run_pipeline

# %%
resultado = run_pipeline()
resultado['kpis']

# %%
resultado['carga']

# %% [markdown]
# Este notebook se usa para demo y defensa. La lógica de carga real queda separada en `carga/carga_datos.py`, mientras que el notebook de carga del directorio `IA_Proyecto/notebooks/` sigue siendo solo material explicativo y de apoyo.
